# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('iris dataset.csv')

df=df.iloc[:-1,:5]
print(df)
# Out:
#      Sepal length  Sepal width  Petal length  Petal width  Species
# 0             4.9          3.1           1.5          0.1      1.0
# 1             6.4          3.1           5.5          1.8      3.0
# 2             4.6          3.1           1.5          0.2      1.0
# 3             6.7          3.0           5.0          1.7      2.0
# 4             4.6          3.6           1.0          0.2      1.0
# ..            ...          ...           ...          ...      ...
# 145           4.6          3.2           1.4          0.2      1.0
# 146           6.4          2.9           4.3          1.3      2.0
# 147           6.7          3.1           5.6          2.4      3.0
# 148           6.8          3.2           5.9          2.3      3.0
# 149           4.9          2.4           3.3          1.0      2.0
#
# [150 rows x 5 columns]

# %%
train_x=df.iloc[0:75,:-1]
train_y=df.iloc[0:75,4:]
test_x=df.iloc[75:,:]
test_y=df.iloc[75:,4:]
print(train_x)
print(train_y)
print(test_x)
print(test_y)
# Out:
#     Sepal length  Sepal width  Petal length  Petal width
# 0            4.9          3.1           1.5          0.1
# 1            6.4          3.1           5.5          1.8
# 2            4.6          3.1           1.5          0.2
# 3            6.7          3.0           5.0          1.7
# 4            4.6          3.6           1.0          0.2
# ..           ...          ...           ...          ...
# 70           4.5          2.3           1.3          0.3
# 71           7.2          3.0           5.8          1.6
# 72           5.0          3.2           1.2          0.2
# 73           5.6          2.7           4.2          1.3
# 74           6.0          2.2           4.0          1.0
#
# [75 rows x 4 columns]
#     Species
# 0       1.0
# 1       3.0
# 2       1.0
# 3       2.0
# 4       1.0
# ..      ...
# 70      1.0
# 71      3.0
# 72      1.0
# 73      2.0
# 74      2.0
#
# [75 rows x 1 columns]
#      Sepal length  Sepal width  Petal length  Petal width  Species
# 75            6.2          2.9           4.3          1.3      2.0
# 76            6.6          3.0           4.4          1.4      2.0
# 77            6.0          2.7           5.1          1.6      2.0
# 78            6.3          2.3           4.4          1.3      2.0
# 79            5.6          2.8           4.9          2.0      3.0
# ..            ...          ...           ...          ...      ...
# 145           4.6          3.2           1.4          0.2      1.0
# 146           6.4          2.9           4.3          1.3      2.0
# 147           6.7          3.1           5.6          2.4      3.0
# 148           6.8          3.2           5.9          2.3      3.0
# 149           4.9          2.4           3.3          1.0      2.0
#
# [75 rows x 5 columns]
#      Species
# 75       2.0
# 76       2.0
# 77       2.0
# 78       2.0
# 79       3.0
# ..       ...
# 145      1.0
# 146      2.0
# 147      3.0
# 148      3.0
# 149      2.0
#
# [75 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

class GradientDescent:
    def __init__(self, iteration, learning_rate, train_x, train_y, test_x, test_y):
        self.iter = iteration
        self.learning_rate = learning_rate
        self.w0 = 0
        self.w1 = 0
        self.w2 = 0
        self.w3 = 0
        self.w4 = 0
        self.train_x = train_x
        self.train_y = train_y
        self.test_x = test_x
        self.test_y = test_y
        self.cost_history = []
        self.accuracy=[]

    def cost_find(self):
        cost = 0
        for i in range(len(self.train_x)):
            y_pred = self.w0 + self.w1 * self.train_x.iloc[i, 0] + self.w2 * self.train_x.iloc[i, 1] + self.w3 * self.train_x.iloc[i, 2] + self.w4 * self.train_x.iloc[i, 3]
            cost += (self.train_y.iloc[i, 0] - y_pred) ** 2
        cost /= (2 * len(self.train_x))
        return cost

    def direction(self):
        d = [0] * 5
        for i in range(len(self.train_x)):
            error = self.train_y.iloc[i, 0] - (self.w0 + self.w1 * self.train_x.iloc[i, 0] + self.w2 * self.train_x.iloc[i, 1] + self.w3 * self.train_x.iloc[i, 2] + self.w4 * self.train_x.iloc[i, 3])
            d[0] += error
            d[1] += error * self.train_x.iloc[i, 0]
            d[2] += error * self.train_x.iloc[i, 1]
            d[3] += error * self.train_x.iloc[i, 2]
            d[4] += error * self.train_x.iloc[i, 3]
        return [-lr for lr in d]

    def update_weight(self, d):
        self.w0 -= self.learning_rate * d[0]
        self.w1 -= self.learning_rate * d[1]
        self.w2 -= self.learning_rate * d[2]
        self.w3 -= self.learning_rate * d[3]
        self.w4 -= self.learning_rate * d[4]

    def gradient_descent(self):
        for i in range(self.iter):
            cost = self.cost_find()
            d = self.direction()
            self.update_weight(d)
            self.cost_history.append(cost)
            if (i+1) % 100 == 0:  # Record cost after every 100 iterations
                print(f"Iteration: {i+1}, Cost: {cost}")
                
            if (i+1) % 1000 == 0:  # Record cost after every 100 iterations   
                self.plot_cost(i+1)
                print(f"Accuracy After {i+1} Iteration")
                self.testing()
        self.plot_accuracy()


    def plot_cost(self,i):
        iterations = range(100, i + 1, 100)
        costs = self.cost_history[99::100]  # Get costs after every 100 iterations
        plt.plot(iterations, costs)
        plt.xlabel('Iterations')
        plt.ylabel('Cost')
        plt.title('Cost vs. Iterations')
        plt.show()
        
    def plot_accuracy(self):
        iterations = range(1000, self.iter+1 , 1000)
#         costs = self.accuracy[999::1000]  # Get costs after every 100 iterations
#         print("costs",costs)
        plt.plot(iterations, self.accuracy)
        plt.xlabel('Iterations')
        plt.ylabel('Accuracy %')
        plt.title('Accuracy vs. Iterations')
        plt.show()
        
   
        
    def cost_test(self,i): 
        y_pred = self.w0 + self.w1 * self.test_x.iloc[i, 0] + self.w2 * self.test_x.iloc[i, 1] + self.w3 * self.test_x.iloc[i, 2] + self.w4 * self.test_x.iloc[i, 3]
        return y_pred
    
#     def class_define(self,y_pred):
#         if(y_pred<=1.5):
#             return 1
#         elif(y_pred >1.5 and y_pred <=2.5):
#             return 2
#         elif(y_pred>2.5):
#             return 3
    
    def testing(self):
        acc=0
        for i in range(len(self.test_x)):
            y_pred=self.cost_test(i)
#             y=self.class_define(y_pred)
#             if(y== test_y.iloc[i,0]):
            if(y_pred == test_y.iloc[i,0]):
                acc=acc+1
        accu=(acc/len(self.test_x))*100
        self.accuracy.append(accu)      
        print("Accuracy : ", (acc/len(self.test_x))*100)
                
if __name__ == "__main__":
    # Define and initialize train_x, train_y, test_x, test_y
    obj = GradientDescent(10000, 0.0001, train_x, train_y, test_x, test_y)
    obj.gradient_descent()
# Out:
# Iteration: 100, Cost: 0.030685912962278745
# Iteration: 200, Cost: 0.02723052585368075
# Iteration: 300, Cost: 0.026869979750123025
# Iteration: 400, Cost: 0.02662987506387388
# Iteration: 500, Cost: 0.026410168390227383
# Iteration: 600, Cost: 0.026206093929216117
# Iteration: 700, Cost: 0.026016173308851864
# Iteration: 800, Cost: 0.025839158582921642
# Iteration: 900, Cost: 0.025673919730017137
# Iteration: 1000, Cost: 0.025519430662945406
# Accuracy After 1000 Iteration
# Accuracy :  0.0
# Iteration: 1100, Cost: 0.025374759458380237
# Iteration: 1200, Cost: 0.025239059596209475
# Iteration: 1300, Cost: 0.025111562020834408
# Iteration: 1400, Cost: 0.02499156794435785
# Iteration: 1500, Cost: 0.0248784423220851
# Iteration: 1600, Cost: 0.024771607937381653
# Iteration: 1700, Cost: 0.0246705400388361
# Iteration: 1800, Cost: 0.02457476147802424
# Iteration: 1900, Cost: 0.02448383830101568
# Iteration: 2000, Cost: 0.024397375751156514
# Accuracy After 2000 Iteration
# Accuracy :  0.0
# Iteration: 2100, Cost: 0.024315014644640445
# Iteration: 2200, Cost: 0.024236428083988265
# Iteration: 2300, Cost: 0.02416131847782264
# Iteration: 2400, Cost: 0.024089414838288574
# Iteration: 2500, Cost: 0.024020470330152977
# Iteration: 2600, Cost: 0.02395426004804957
# Iteration: 2700, Cost: 0.0238905790005406
# Iteration: 2800, Cost: 0.023829240281663427
# Iteration: 2900, Cost: 0.02377007341244159
# Iteration: 3000, Cost: 0.02371292283648035
# Accuracy After 3000 Iteration
# Accuracy :  0.0
# Iteration: 3100, Cost: 0.023657646555253778
# Iteration: 3200, Cost: 0.023604114890037938
# Iteration: 3300, Cost: 0.023552209358666483
# Iteration: 3400, Cost: 0.02350182165639113
# Iteration: 3500, Cost: 0.02345285273113332
# Iteration: 3600, Cost: 0.02340521194432192
# Iteration: 3700, Cost: 0.023358816309335992
# Iteration: 3800, Cost: 0.023313589800318394
# Iteration: 3900, Cost: 0.02326946272480244
# Iteration: 4000, Cost: 0.02322637115420771
# Accuracy After 4000 Iteration
# Accuracy :  0.0
# Iteration: 4100, Cost: 0.02318425640681635
# Iteration: 4200, Cost: 0.023143064578345272
# Iteration: 4300, Cost: 0.023102746115686877
# Iteration: 4400, Cost: 0.0230632554298033
# Iteration: 4500, Cost: 0.02302455054413598
# Iteration: 4600, Cost: 0.022986592775231064
# Iteration: 4700, Cost: 0.022949346442589797
# Iteration: 4800, Cost: 0.022912778605032387
