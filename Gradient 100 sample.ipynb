# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('iris dataset.csv')

df=df.iloc[:-1,:5]
print(df)
# Out:
#      Sepal length  Sepal width  Petal length  Petal width  Species
# 0             4.9          3.1           1.5          0.1      1.0
# 1             6.4          3.1           5.5          1.8      3.0
# 2             4.6          3.1           1.5          0.2      1.0
# 3             6.7          3.0           5.0          1.7      2.0
# 4             4.6          3.6           1.0          0.2      1.0
# ..            ...          ...           ...          ...      ...
# 145           4.6          3.2           1.4          0.2      1.0
# 146           6.4          2.9           4.3          1.3      2.0
# 147           6.7          3.1           5.6          2.4      3.0
# 148           6.8          3.2           5.9          2.3      3.0
# 149           4.9          2.4           3.3          1.0      2.0
#
# [150 rows x 5 columns]

# %%
train_x=df.iloc[0:100,:-1]
train_y=df.iloc[0:100,4:]
test_x=df.iloc[100:,:]
test_y=df.iloc[100:,4:]
print(train_x)
print(train_y)
print(test_x)
print(test_y)
# Out:
#     Sepal length  Sepal width  Petal length  Petal width
# 0            4.9          3.1           1.5          0.1
# 1            6.4          3.1           5.5          1.8
# 2            4.6          3.1           1.5          0.2
# 3            6.7          3.0           5.0          1.7
# 4            4.6          3.6           1.0          0.2
# ..           ...          ...           ...          ...
# 95           5.0          3.4           1.6          0.4
# 96           4.7          3.2           1.6          0.2
# 97           6.5          2.8           4.6          1.5
# 98           5.5          2.5           4.0          1.3
# 99           5.9          3.2           4.8          1.8
#
# [100 rows x 4 columns]
#     Species
# 0       1.0
# 1       3.0
# 2       1.0
# 3       2.0
# 4       1.0
# ..      ...
# 95      1.0
# 96      1.0
# 97      2.0
# 98      2.0
# 99      2.0
#
# [100 rows x 1 columns]
#      Sepal length  Sepal width  Petal length  Petal width  Species
# 100           6.5          3.0           5.8          2.2      3.0
# 101           5.2          3.4           1.4          0.2      1.0
# 102           4.9          3.0           1.4          0.2      1.0
# 103           6.7          3.3           5.7          2.1      3.0
# 104           5.0          3.3           1.4          0.2      1.0
# 105           5.8          4.0           1.2          0.2      1.0
# 106           4.9          2.5           4.5          1.7      3.0
# 107           5.9          3.0           5.1          1.8      3.0
# 108           5.1          3.5           1.4          0.2      1.0
# 109           6.2          2.2           4.5          1.5      2.0
# 110           5.7          2.9           4.2          1.3      2.0
# 111           5.5          3.5           1.3          0.2      1.0
# 112           5.5          2.3           4.0          1.3      2.0
# 113           5.8          2.7           5.1          1.9      3.0
# 114           6.7          2.5           5.8          1.8      3.0
# 115           7.7          2.6           6.9          2.3      3.0
# 116           6.0          3.4           4.5          1.6      2.0
# 117           5.7          2.5           5.0          2.0      3.0
# 118           5.9          3.0           4.2          1.5      2.0
# 119           6.1          2.8           4.7          1.2      2.0
# 120           6.2          2.8           4.8          1.8      3.0
# 121           7.9          3.8           6.4          2.0      3.0
# 122           7.2          3.6           6.1          2.5      3.0
# 123           5.4          3.4           1.7          0.2      1.0
# 124           4.4          3.0           1.3          0.2      1.0
# 125           7.7          2.8           6.7          2.0      3.0
# 126           5.5          2.4           3.7          1.0      2.0
# 127           5.1          3.8           1.5          0.3      1.0
# 128           4.6          3.4           1.4          0.3      1.0
# 129           5.0          3.5           1.3          0.3      1.0
# 130           5.0          2.3           3.3          1.0      2.0
# 131           5.8          2.6           4.0          1.2      2.0
# 132           7.4          2.8           6.1          1.9      3.0
# 133           6.7          3.1           4.4          1.4      2.0
# 134           6.1          2.9           4.7          1.4      2.0
# 135           4.8          3.0           1.4          0.1      1.0
# 136           5.0          2.0           3.5          1.0      2.0
# 137           4.7          3.2           1.3          0.2      1.0
# 138           5.2          4.1           1.5          0.1      1.0
# 139           6.3          2.5           5.0          1.9      3.0
# 140           6.4          2.7           5.3          1.9      3.0
# 141           6.7          3.3           5.7          2.5      3.0
# 142           5.4          3.0           4.5          1.5      2.0
# 143           6.5          3.0           5.2          2.0      3.0
# 144           6.3          2.5           4.9          1.5      2.0
# 145           4.6          3.2           1.4          0.2      1.0
# 146           6.4          2.9           4.3          1.3      2.0
# 147           6.7          3.1           5.6          2.4      3.0
# 148           6.8          3.2           5.9          2.3      3.0
# 149           4.9          2.4           3.3          1.0      2.0
#      Species
# 100      3.0
# 101      1.0
# 102      1.0
# 103      3.0
# 104      1.0
# 105      1.0
# 106      3.0
# 107      3.0
# 108      1.0
# 109      2.0
# 110      2.0
# 111      1.0
# 112      2.0
# 113      3.0
# 114      3.0
# 115      3.0
# 116      2.0
# 117      3.0
# 118      2.0
# 119      2.0
# 120      3.0
# 121      3.0
# 122      3.0
# 123      1.0
# 124      1.0
# 125      3.0
# 126      2.0
# 127      1.0
# 128      1.0
# 129      1.0
# 130      2.0
# 131      2.0
# 132      3.0
# 133      2.0
# 134      2.0
# 135      1.0
# 136      2.0
# 137      1.0
# 138      1.0
# 139      3.0
# 140      3.0
# 141      3.0
# 142      2.0
# 143      3.0
# 144      2.0
# 145      1.0
# 146      2.0
# 147      3.0
# 148      3.0
# 149      2.0

# %%
import matplotlib.pyplot as plt

class GradientDescent:
    def __init__(self, iteration, learning_rate, train_x, train_y, test_x, test_y):
        self.iter = iteration
        self.learning_rate = learning_rate
        self.w0 = 0
        self.w1 = 0
        self.w2 = 0
        self.w3 = 0
        self.w4 = 0
        self.train_x = train_x
        self.train_y = train_y
        self.test_x = test_x
        self.test_y = test_y
        self.cost_history = []
        self.accuracy=[]

    def cost_find(self):
        cost = 0
        for i in range(len(self.train_x)):
            y_pred = self.w0 + self.w1 * self.train_x.iloc[i, 0] + self.w2 * self.train_x.iloc[i, 1] + self.w3 * self.train_x.iloc[i, 2] + self.w4 * self.train_x.iloc[i, 3]
            cost += (self.train_y.iloc[i, 0] - y_pred) ** 2
        cost /= (2 * len(self.train_x))
        return cost

    def direction(self):
        d = [0] * 5
        for i in range(len(self.train_x)):
            error = self.train_y.iloc[i, 0] - (self.w0 + self.w1 * self.train_x.iloc[i, 0] + self.w2 * self.train_x.iloc[i, 1] + self.w3 * self.train_x.iloc[i, 2] + self.w4 * self.train_x.iloc[i, 3])
            d[0] += error
            d[1] += error * self.train_x.iloc[i, 0]
            d[2] += error * self.train_x.iloc[i, 1]
            d[3] += error * self.train_x.iloc[i, 2]
            d[4] += error * self.train_x.iloc[i, 3]
        return [-lr for lr in d]

    def update_weight(self, d):
        self.w0 -= self.learning_rate * d[0]
        self.w1 -= self.learning_rate * d[1]
        self.w2 -= self.learning_rate * d[2]
        self.w3 -= self.learning_rate * d[3]
        self.w4 -= self.learning_rate * d[4]

    def gradient_descent(self):
        for i in range(self.iter):
            cost = self.cost_find()
            d = self.direction()
            self.update_weight(d)
            self.cost_history.append(cost)
            if (i+1) % 100 == 0:  # Record cost after every 100 iterations
                print(f"Iteration: {i+1}, Cost: {cost}")
            if (i+1) % 1000 == 0:  # Record cost after every 100 iterations   
                self.plot_cost(i+1)
                print(f"Accuracy After {i+1} Iteration")
                self.testing()
        self.plot_accuracy()

    def plot_cost(self,i):
        iterations = range(100, i+1, 100)
        costs = self.cost_history[99::100]  # Get costs after every 100 iterations
        plt.plot(iterations, costs)
        plt.xlabel('Iterations')
        plt.ylabel('Cost')
        plt.title('Cost vs. Iterations')
        plt.show()
        
    def plot_accuracy(self):
        iterations = range(1000, self.iter+1 , 1000)
        plt.plot(iterations, self.accuracy)
        plt.xlabel('Iterations')
        plt.ylabel('Accuracy %')
        plt.title('Accuracy vs. Iterations')
        plt.show()
        
    def cost_test(self,i): 
        y_pred = self.w0 + self.w1 * self.test_x.iloc[i, 0] + self.w2 * self.test_x.iloc[i, 1] + self.w3 * self.test_x.iloc[i, 2] + self.w4 * self.test_x.iloc[i, 3]
        return y_pred
    
    def class_define(self,y_pred):
        if(y_pred<=1.5):
            return 1
        elif(y_pred >1.5 and y_pred <=2.5):
            return 2
        elif(y_pred>2.5):
            return 3
    
    def testing(self):
        acc=0
        for i in range(len(self.test_x)):
            y_pred=self.cost_test(i)
            y=self.class_define(y_pred)
            if(y== test_y.iloc[i,0]):
                acc=acc+1
        accu=(acc/len(self.test_x))*100
        self.accuracy.append(accu)
        print("Accuracy : ", (acc/len(self.test_x))*100)
                
if __name__ == "__main__":
    # Define and initialize train_x, train_y, test_x, test_y
    obj = GradientDescent(10000, 0.0001, train_x, train_y, test_x, test_y)
    obj.gradient_descent()
# Out:
# Iteration: 100, Cost: 0.03322138921768394
# Iteration: 200, Cost: 0.03138803258999596
# Iteration: 300, Cost: 0.030896939642575196
# Iteration: 400, Cost: 0.0304827329778509
# Iteration: 500, Cost: 0.03011916151923384
# Iteration: 600, Cost: 0.029798927930618495
# Iteration: 700, Cost: 0.02951599737868741
# Iteration: 800, Cost: 0.029265200888001296
# Iteration: 900, Cost: 0.029042107649424085
# Iteration: 1000, Cost: 0.02884291878472591
# Accuracy After 1000 Iteration
# Accuracy :  96.0
# Iteration: 1100, Cost: 0.0286643764736211
# Iteration: 1200, Cost: 0.0285036861831771
# Iteration: 1300, Cost: 0.028358450108211378
# Iteration: 1400, Cost: 0.02822661020493021
# Iteration: 1500, Cost: 0.028106399433595494
# Iteration: 1600, Cost: 0.027996300025812753
# Iteration: 1700, Cost: 0.027895007762997186
# Iteration: 1800, Cost: 0.027801401398854116
# Iteration: 1900, Cost: 0.027714516483874258
# Iteration: 2000, Cost: 0.02763352295693714
# Accuracy After 2000 Iteration
# Accuracy :  98.0
# Iteration: 2100, Cost: 0.02755770596075072
# Iteration: 2200, Cost: 0.027486449416259752
# Iteration: 2300, Cost: 0.0274192219582426
# Iteration: 2400, Cost: 0.027355564891719107
# Iteration: 2500, Cost: 0.027295081877907496
# Iteration: 2600, Cost: 0.02723743010049545
# Iteration: 2700, Cost: 0.02718231269894974
# Iteration: 2800, Cost: 0.027129472286358647
# Iteration: 2900, Cost: 0.027078685395628747
# Iteration: 3000, Cost: 0.02702975772038599
# Accuracy After 3000 Iteration
# Accuracy :  98.0
# Iteration: 3100, Cost: 0.026982520036207873
# Iteration: 3200, Cost: 0.026936824704306916
# Iteration: 3300, Cost: 0.0268925426739003
# Iteration: 3400, Cost: 0.026849560911577194
# Iteration: 3500, Cost: 0.026807780196309895
# Iteration: 3600, Cost: 0.02676711322759743
# Iteration: 3700, Cost: 0.026727483001797992
